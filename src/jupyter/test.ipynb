# %%
import numpy as np
import pandas as pd
import sklearn as sk

print("Hello, Sleepy AI!")
dataFrame = pd.DataFrame(np.random.rand(5, 3), columns=["A", "B", "C"])
print(dataFrame)

print(sk.__version__)
# Out:
# Hello, Sleepy AI!
#           A         B         C
# 0  0.138529  0.841146  0.764880
# 1  0.466427  0.755331  0.284715
# 2  0.772319  0.433054  0.187171
# 3  0.873094  0.491982  0.262151
# 4  0.465410  0.149961  0.075914
# 1.8.0
