# %%
import Preprocessing as pp
import Data_management as dm

import os
import wfdb
import pandas as pd
import numpy as np


record = "tr03-0146"
channel_index = 11  # SpO2 channel

# In notebooks, __file__ doesn't exist, so use relative path
record_path = os.path.join("..", "data", record)
print(record_path)

df = dm.load_from_mat_and_arousal_to_pandas(record_path)
df
# Out:
# ../data/tr03-0146
#             time_s  sao2_percent  is_apnea  is_hypopnea
# 0            0.000     92.574960         0            0
# 1            0.005     92.574960         0            0
# 2            0.010     92.574960         0            0
# 3            0.015     92.574960         0            0
# 4            0.020     92.574960         0            0
# ...            ...           ...       ...          ...
# 5578995  27894.975      0.495918         0            0
# 5578996  27894.980      0.495918         0            0
# 5578997  27894.985      0.495918         0            0
# 5578998  27894.990      0.495918         0            0
# 5578999  27894.995      0.495918         0            0
#
# [5579000 rows x 4 columns]
